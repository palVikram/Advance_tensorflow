# %% [markdown]
# <a href="https://colab.research.google.com/github/palVikram/Advance_tensorflow/blob/main/convolution_layer_inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import misc

ascent_image=misc.ascent()

# %%
import matplotlib.pyplot as plt

#visualize the image
plt.grid(False)
plt.gray()
plt.axis()
plt.imshow(ascent_image)
plt.show()

# %%
from matplotlib import image
import numpy as np

image_transformed=np.copy(ascent_image)

size_x=image_transformed.shape[0]
size_y=image_transformed.shape[1]

size_x,size_y
# Out:
# (512, 512)

# %%
### share edges
filter=[[0,1,0],[1,-4,1],[0,1,0]]



weight=1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
    convolution=0.0

    convolution=convolution+(ascent_image[x-1,y-1]*filter[0][0])
    convolution=convolution+(ascent_image[x-1,y]*filter[0][1])
    convolution=convolution+(ascent_image[x-1,y+1]*filter[0][2])
    convolution=convolution+(ascent_image[x,y-1]*filter[1][0])
    convolution=convolution+(ascent_image[x,y]*filter[1][1])
    convolution=convolution+(ascent_image[x,y+1]*filter[1][2])
    convolution=convolution+(ascent_image[x+1,y-1]*filter[2][0])
    convolution=convolution+(ascent_image[x+1,y]*filter[2][1])
    convolution=convolution+(ascent_image[x+1,y+1]*filter[2][2])

    convolution=convolution*weight

    if convolution < 0:
      convolution=0
    if convolution >255: 
      convolution=255

    image_transformed[x][y]=convolution

# %%
## plot the image and note the size of the axes --they are 512 by 512 
plt.gray()
plt.grid(False)

plt.imshow(image_transformed)
plt.show()
