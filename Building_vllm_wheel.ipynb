# %% [markdown]
# <a href="https://colab.research.google.com/github/palVikram/Advance_tensorflow/blob/main/Building_vllm_wheel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vllm-project/vllm.git
# Out:
# Cloning into 'vllm'...
# remote: Enumerating objects: 12520, done.
# remote: Counting objects: 100% (4588/4588), done.
# remote: Compressing objects: 100% (892/892), done.
# remote: Total 12520 (delta 4049), reused 3851 (delta 3695), pack-reused 7932
# Receiving objects: 100% (12520/12520), 6.50 MiB | 16.12 MiB/s, done.
# Resolving deltas: 100% (9395/9395), done.

# %%
cd vllm
# Out:
# /content/vllm

# %%
ls
# Out:
# benchmarks/      Dockerfile.rocm  MANIFEST.in             requirements-dev.txt     setup.py
# collect_env.py   docs/            patch_xformers.rocm.sh  requirements-neuron.txt  tests/
# CONTRIBUTING.md  examples/        pyproject.toml          requirements-rocm.txt    vllm/
# csrc/            format.sh*       README.md               requirements.txt
# Dockerfile       LICENSE          requirements-build.txt  rocm_patch/

# %%
# !python setup.py bdist_wheel
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running bdist_wheel
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:500: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/utils.py -> build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/test_utils.py -> build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/block.py -> build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/sequence.py -> build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/sampling_params.py -> build/lib.linux-x86_64-cpython-310/vllm
# copying vllm/logger.py -> build/lib.linux-x86_64-cpython-310/vllm
# ...

# %%
cd dist
# Out:
# /content/vllm/dist

# %%
# !pip install /content/vllm/dist/vllm-0.3.3+cu122-cp310-cp310-linux_x86_64.whl
# Out:
# Processing ./vllm-0.3.3+cu122-cp310-cp310-linux_x86_64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.0 MB/s eta 0:00:00
# ...

# %%
pwd
# Out:
# '/content/vllm/dist'

# %%
from vllm import LLM

# %%
pip show vllm
# Out:
# Name: vllm
# Version: 0.3.3+cu122
# Summary: A high-throughput and memory-efficient inference and serving engine for LLMs
# Home-page: https://github.com/vllm-project/vllm
# Author: vLLM Team
# Author-email:
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: cupy-cuda12x, fastapi, ninja, numpy, outlines, prometheus-client, psutil, pydantic, pynvml, ray, sentencepiece, torch, transformers, triton, uvicorn, xformers
# Required-by:

# %%
cd /usr/local/lib/python3.10/dist-packages
# Out:
# /usr/local/lib/python3.10/dist-packages

# %%
cd vllm
# Out:
# /usr/local/lib/python3.10/dist-packages/vllm

# %%
ls
# Out:
# block.py                             __init__.py                              py.typed
# _C.cpython-310-x86_64-linux-gnu.so*  logger.py                                sampling_params.py
# config.py                            lora/                                    sequence.py
# core/                                model_executor/                          test_utils.py
# engine/                              _moe_C.cpython-310-x86_64-linux-gnu.so*  transformers_utils/
# entrypoints/                         outputs.py                               utils.py
# executor/                            __pycache__/                             worker/
